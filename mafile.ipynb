# %%
import pandas as pd
credits = pd.read_csv("the-movies-dataset/credits.csv")
#keywords = pd.read_csv("the-movies-dataset/keywords.csv")
#links = pd.read_csv("the-movies-dataset/links.csv")
#ratings = pd.read_csv("the-movies-dataset/ratings.csv")

# %%
metadata = pd.read_csv("the-movies-dataset/movies_metadata.csv")

# %%
import json

# %%
import csv

with open("the-movies-dataset/credits.csv") as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    for i in range (0,1):
        #print(row[0])
        data = row[0]
        #print(['cast_id'][0])
        #print(row[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b7112d34f808> in <module>()
#       5     for i in range (0,1):
#       6         #print(row[0])
# ----> 7         data = row[0]
#       8         #print(['cast_id'][0])
#       9         #print(row[0])
#
# NameError: name 'row' is not defined

# %%
from ast import literal_eval

python_dict = literal_eval(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1548ea7593e8> in <module>()
#       2 from ast import literal_eval
#       3
# ----> 4 python_dict = literal_eval(data)
#
# NameError: name 'data' is not defined

# %%
#tempdic = literal_eval(credits['cast'][1])

# %%
python_dict = [];

# %%
#len(credits)

# %%
python_dict = [];
for i in range(0,10):
    tempdic = literal_eval(credits['cast'][i])
    python_dict = tempdic +python_dict

# %%
len(python_dict)
# Out:
# 223

# %%
python_dict[0]
# Out:
# {'cast_id': 1,
#  'character': 'James Bond',
#  'credit_id': '52fe426ec3a36847f801e10d',
#  'gender': 2,
#  'id': 517,
#  'name': 'Pierce Brosnan',
#  'order': 0,
#  'profile_path': '/1JXL0zrA26JjdoX8sqf57fJRDVM.jpg'}

# %%
df =pd.DataFrame(python_dict)

# %%
print(df.head(1))
# Out:
#    cast_id   character                 credit_id  gender   id            name  \
# 0        1  James Bond  52fe426ec3a36847f801e10d       2  517  Pierce Brosnan
#
#    order                      profile_path
# 0      0  /1JXL0zrA26JjdoX8sqf57fJRDVM.jpg

# %%
print(df)
# Out:
#      cast_id                           character                 credit_id  \
# 0          1                          James Bond  52fe426ec3a36847f801e10d
# 1          2                      Alec Trevelyan  52fe426ec3a36847f801e111
# 2          3         Natalya Fyodorovna Simonova  52fe426ec3a36847f801e115
# 3          4                       Xenia Onatopp  52fe426ec3a36847f801e119
# 4          5                           Jack Wade  52fe426ec3a36847f801e11d
# 5          6                                   M  52fe426ec3a36847f801e121
# 6          7  General Arkady Grigorovich Ourumov  52fe426ec3a36847f801e125
# 7          8        Valentin Dmitrovich Zukovsky  52fe426ec3a36847f801e129
# 8          9                     Boris Grishenko  52fe426ec3a36847f801e12d
# 9         10     Defense Minister Dmitri Mishkin  52fe426ec3a36847f801e131
# 10        11                                   Q  52fe426ec3a36847f801e135
# ...

# %%
temp[0:20]
# Out:
# '"[{\'cast_id\': 1, \'ch'

# %%
temp[0:15]
# Out:
# '"[{\'cast_id\': 1'

# %%
json.dumps("?")
# Out:
# '"?"'

# %%
credits.dtypes
# Out:
# cast    object
# crew    object
# id       int64
# dtype: object

# %%
print(metadata.shape)
cleanmeta = metadata[(metadata['adult'] == 'False') & (metadata['revenue'] != 0) ]
print(cleanmeta.shape)
cleanmeta['budget'] = cleanmeta.budget.astype(float)
#leanmeta.dtypes
cleanmeta2 = cleanmeta[(cleanmeta['budget'] != 0 )]
print(cleanmeta2.shape)
cleanmeta2
# Out:
# (45466, 24)
# (7411, 24)

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# adult                     object
# belongs_to_collection     object
# budget                   float64
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# ...

# %%
# Out:
# (5381, 24)
#        adult                              belongs_to_collection       budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...   30000000.0
# 1      False                                                NaN   65000000.0
# 3      False                                                NaN   16000000.0
# 5      False                                                NaN   60000000.0
# 8      False                                                NaN   35000000.0
# 9      False  {'id': 645, 'name': 'James Bond Collection', '...   58000000.0
# 10     False                                                NaN   62000000.0
# 13     False                                                NaN   44000000.0
# 14     False                                                NaN   98000000.0
# 15     False                                                NaN   52000000.0
# 16     False                                                NaN   16500000.0
# ...

# %%
cleanmeta.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                   float64
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
print(metadata.shape)
cleanmeta = metadata[(metadata['adult'] == 'False') & (metadata['revenue'] != 0) & (metadata['budget']!=0)]
print(cleanmeta.shape)
#cleanmeta.head()
# Out:
# (45466, 24)
# (7411, 24)

# %%
# Out:
# (45466,)

# %%
cleanmeta
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#          ...
# 45436    True
# 45437    True
# 45438    True
# 45439    True
# 45440    True
# 45441    True
# 45442    True
# 45443    True
# 45444    True
# 45445    True
# 45446    True
# 45447    True
# 45448    True
# 45449    True
# 45450    True
# 45451    True
# 45452    True
# 45453    True
# 45454    True
# 45455    True
# 45456    True
# 45457    True
# 45458    True
# 45459    True
# 45460    True
# 45461    True
# 45462    True
# 45463    True
# 45464    True
# 45465    True
# ...

# %% [markdown]
# print(result.iloc[0])

# %% [markdown]
# need multiple column for multiple actors and crews
# credits: cast: gender,id(represents actor name)
#          crew: department(how to convert to #),gender,id
# do we need multiple column as well? is there a way to iterate one elemnt in df
# keywords: id
# links: movieId, imdvId,
# movies_metadata: budget,genre(id,multiple),id,original language?,popularity,production company(id,multiple),production company(need to convert to #),release date, revenue,runtime,
# ##: excluding original title(id indicates title),non-adult, released movie only
# ratings: userid, movieId,rating,timestamp
