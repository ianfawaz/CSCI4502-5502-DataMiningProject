# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
cleanmeta = pd.read_csv("cleanmeta.csv")
cleanmeta = cleanmeta[['budget','revenue','popularity','runtime','castRevBudRatio']]
cleanmeta = cleanmeta.dropna()
X = cleanmeta[['budget','revenue','popularity','runtime','castRevBudRatio']]
y = cleanmeta['revenue']/cleanmeta['budget']

# %%
X_train = X[:4500]
X_test = X[4500:]

y_train = y[:4500]
y_test = y[4500:]
reg = LinearRegression()

# Train the model using the training sets
reg.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = reg.predict(X_test)
#reg.coef_
# reg.intercept_ 
#reg.predict(np.array([[3, 5]]))b

# %%
reg.score(X_train,y_train)
# Out:
# 0.004501888194809899

# %%
print('Coefficients budget: \n', reg.coef_[0])
print('Coefficients revenue: \n', reg.coef_[1])
print('Coefficients popularity: \n', reg.coef_[2])
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients budget:
#  -0.00014210781744740625
# Coefficients revenue:
#  1.9553141984670207e-05
# Coefficients popularity:
#  -450.15282593800623
# Mean squared error: 1355371891.11
# Variance score: -0.20

# %%
#max(y_pred)
#min(y_pred)
#y_pred.argmin()
# Out:
# 296

# %%
X_test[0]
# Out:
# array([100000000.0, 243400000.0, 19.606895], dtype=object)

# %%
#number = []
b = []
r =[]
p=[]
for i in range(0,len(X_test)):
    #number.append(i)
    b.append(X_test[i][0]) #budget
    r.append(X_test[i][1]) #revenue
    p.append(X_test[i][2]) #popularity

# %%
b_sorted, y_pred_sorted = zip(*sorted(zip(b, y_pred)))

# %%
plt.plot(b_sorted,y_pred_sorted)
plt.title("r/b ratio with budget")
plt.ylabel("r/b ratio")
plt.xlabel("budget")
# Out:
# Text(0.5,0,'budget')

# %%
r_sorted, y_pred_sorted = zip(*sorted(zip(r, y_pred)))

# %%
plt.plot(r_sorted,y_pred_sorted)
plt.title("r/b ratio with revenue")
plt.ylabel("r/b ratio")
plt.xlabel("revenue")
# Out:
# Text(0.5,0,'revenue')

# %%
r_sorted, y_pred_sorted = zip(*sorted(zip(r, y_pred)))
plt.plot(r_sorted,y_pred_sorted)
plt.title("r/b ratio with revenue")
plt.ylabel("r/b ratio")
plt.xlabel("revenue")
# Out:
# str
