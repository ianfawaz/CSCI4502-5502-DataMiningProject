# %%
import pandas as pd
credits = pd.read_csv("the-movies-dataset/credits.csv")
keywords = pd.read_csv("the-movies-dataset/keywords.csv")
links = pd.read_csv("the-movies-dataset/links.csv")
metadata = pd.read_csv("the-movies-dataset/movies_metadata.csv")
ratings = pd.read_csv("the-movies-dataset/ratings.csv")
# Out:
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(credits['cast'].iloc[0])
# Out:
# [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH4
# ...

# %%
result = pd.merge(credits, keywords, on='id')

# %%
temp = pd.merge(metadata,links, on = 'imdbID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'imdbID'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
temp2 = pd.merge(temp,ratins, on='movie')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0ccbbcece409> in <module>()
# ----> 1 temp2 = pd.merge(temp,ratins, on='movie')
#
# NameError: name 'temp' is not defined

# %% [markdown]
# print(result.iloc[0])

# %%
import pandas as pd
credits = pd.read_csv("the-movies-dataset/credits.csv")
keywords = pd.read_csv("the-movies-dataset/keywords.csv")
links = pd.read_csv("the-movies-dataset/links.csv")
metadata = pd.read_csv("the-movies-dataset/movies_metadata.csv")
ratings = pd.read_csv("the-movies-dataset/ratings.csv")
# Out:
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(credits['cast'].iloc[0])
# Out:
# [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH4
# ...

# %%
print(metadata.shape)
cleanmeta = metadata[(metadata['adult'] == 'False') & (metadata['revenue'] != 0)]
cleanmeta['budget'] = cleanmeta.budget.astype(float)
cleanmeta['id'] = cleanmeta.id.astype(int)

cleanmeta = cleanmeta[cleanmeta['budget']!=0]
print(cleanmeta.shape)
cleanmeta.head()
# Out:
# (45466, 24)
# (5381, 24)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#    adult                              belongs_to_collection      budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# ...

# %%
result = pd.merge(credits, keywords, on='id')
result.head(100)
# Out:
#                                                  cast  \
# 0   [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2   [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4   [{'cast_id': 1, 'character': 'George Banks', '...
# 5   [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 6   [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 7   [{'cast_id': 2, 'character': 'Tom Sawyer', 'cr...
# 8   [{'cast_id': 1, 'character': 'Darren Francis T...
# 9   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 10  [{'cast_id': 1, 'character': 'Andrew Shepherd'...
# 11  [{'cast_id': 9, 'character': 'Count Dracula', ...
# 12  [{'cast_id': 1, 'character': 'Balto (voice)', ...
# 13  [{'cast_id': 1, 'character': 'Richard Nixon', ...
# 14  [{'cast_id': 1, 'character': 'Morgan Adams', '...
# 15  [{'cast_id': 4, 'character': "Sam 'Ace' Rothst...
# ...

# %%
temp = pd.merge(links, ratings, on = 'movieId')
temp.head()
# Out:
#    movieId  imdbId  tmdbId  userId  rating   timestamp
# 0        1  114709   862.0       8     4.0  1013443596
# 1        1  114709   862.0       9     4.5  1073837180
# 2        1  114709   862.0      12     4.0   943912205
# 3        1  114709   862.0      20     4.0  1368361348
# 4        1  114709   862.0      24     4.0   979869938

# %%
temp2 = pd.merge(result,metadata, on='id')
temp2.head()
# Out:
# Empty DataFrame
# Columns: [cast, crew, id, keywords, adult, belongs_to_collection, budget, genres, homepage, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# print(result.iloc[0])

# %%
#actors = pd.merge(credits, metadata, on='id')
# cleanmeta.merge(credits, left_on='id', right_on='id', how='inner')
# print(cleanmeta)
cleanmeta = pd.merge(credits, cleanmeta, on='id')
cleanmeta.head(100)
# actors.head()
#actors.head()
#print(credits.head())
#print(actors['cast'][0])


#credits.set_index('id').join(cleanmeta.set_index('id'))
# Out:
#                                                  cast  \
# 0   [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3   [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4   [{'cast_id': 1, 'character': 'Darren Francis T...
# 5   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 6   [{'cast_id': 1, 'character': 'Andrew Shepherd'...
# 7   [{'cast_id': 1, 'character': 'Richard Nixon', ...
# 8   [{'cast_id': 1, 'character': 'Morgan Adams', '...
# 9   [{'cast_id': 4, 'character': "Sam 'Ace' Rothst...
# 10  [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# 11  [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 12  [{'cast_id': 1, 'character': 'Ace Ventura', 'c...
# 13  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 14  [{'cast_id': 1, 'character': 'Chili Palmer', '...
# 15  [{'cast_id': 1, 'character': 'Robert Rath', 'c...
# ...

# %%
# import json
# actorsstring = actors['cast'][0]
# actorsstring = actorsstring.replace("\'", "\"")
# parsed_json = json.loads(actorsstring)
from ast import literal_eval

# python_dict = literal_eval(actors['cast'][0])
# python_dict[0]['character']

python_dict = [];
for i in range(len(cleanmeta)):
    tempdic = literal_eval(cleanmeta['cast'][i])
    python_dict = tempdic +python_dict
actordict = pd.DataFrame(python_dict)

actordict.drop_duplicates(subset='id',inplace=True)
actordict.sort_values(by='id', inplace=True)
actordict.head(5000)
# Out:
#         cast_id                         character                 credit_id  \
# 69723        78                   Baron Papanoida  584a4128c3a368141f01b620
# 6360          0                 The Joker (voice)  56bde12c925141734d003684
# 16885         2                     William Jones  54720ed292514112e70085bb
# 19171         7              Princess Leia Organa  52fe4a959251416c750e7137
# 85184        14                       Buchhändler  52fe44b7c3a36847f80a61bf
# 4023        114                             C-3PO  585375739251411a4602b913
# 8406         22                     Crush (voice)  5711829b9251410a68000ae0
# 45760        57          Additional Voice (voice)  5617f1659251412af2002fd7
# 1191         54                       Chick Hicks  59443007c3a36816f60002d5
# 8410         27            Passenger Carl (voice)  575a9ef6c3a3684188000f8c
# 8395          3                    Marlin (voice)  52fe4af8c3a368484e1707af
# ...

# %% [markdown]
# need multiple column for multiple actors and crews
# credits: cast: gender,id(represents actor name)
#          crew: department(how to convert to #),gender,id
# do we need multiple column as well? is there a way to iterate one elemnt in df
# keywords: id
# links: movieId, imdvId,
# movies_metadata: budget,genre(id,multiple),id,original language?,popularity,production company(id,multiple),production company(need to convert to #),release date, revenue,runtime,
# ##: excluding original title(id indicates title),non-adult, released movie only
# ratings: userid, movieId,rating,timestamp

# %%
from pandas import Series
actordict['movieIDs'] = Series('', index=actordict.index)

# %%
for i in range(1000):
    castlist = (literal_eval(cleanmeta['cast'][i]))
    for cast in castlist:
        actordict.loc[actordict['id'] == cast['id'], 'movieIDs'] = actordict.loc[actordict['id'] == cast['id'], 'movieIDs'] + str(cleanmeta['id'][i])+','

# %%
actordict.head(2000)
# Out:
#         cast_id                                          character  \
# 69723        78                                    Baron Papanoida
# 6360          0                                  The Joker (voice)
# 16885         2                                      William Jones
# 19171         7                               Princess Leia Organa
# 85184        14                                        Buchhändler
# 4023        114                                              C-3PO
# 8406         22                                      Crush (voice)
# 45760        57                           Additional Voice (voice)
# 1191         54                                        Chick Hicks
# 8410         27                             Passenger Carl (voice)
# 8395          3                                     Marlin (voice)
# 8394          2                                       Dory (voice)
# 7368         26                                      Krang (voice)
# ...

# %%
#print(actordict['movieIDs'].values[0])
for i in range(len(actordict)):
    #print(actordict['movieIDs'].values[i])
    if not actordict['movieIDs'].values[i] == '':
        listActor = actordict['movieIDs'].values[i][:-1].split(',')
        #print(listActor)
        setActor = set(listActor)
        stringActor = str(list(setActor))
        #print(stringActor)
        actordict['movieIDs'].values[i] = stringActor
actordict['movieIDs']
# Out:
# 69723                                        ['87', '306']
# 6360                                ['1891', '1892', '11']
# 16885    ['78', '28', '1892', '4477', '11', '3525', '60...
# 19171    ['1892', '525', '11', '816', '1891', '639', '1...
# 85184                                               ['11']
# 4023                 ['1892', '11', '123', '1891', '1893']
# 8406
# 45760
# 1191
# 8410
# 8395                      ['3050', '103', '1389', '12626']
# 8394                                              ['3050']
# 7368                                      ['8839', '9487']
# 5709     ['4951', '6068', '10490', '9403', '17127', '47...
# 7211                                               ['888']
# 32805                                             ['6116']
# 44415                                     ['10409', '236']
# 4750     ['10466', '13', '9800', '568', '858', '862', '...
# 11948                              ['2493', '10207', '13']
# ...

# %%
cleanmeta = pd.merge(credits, cleanmeta, on='id')
cleanmeta.head(100)

from ast import literal_eval

python_dict = [];
for i in range(len(cleanmeta)):
    tempdic = literal_eval(cleanmeta['crew'][i])
    python_dict = tempdic +python_dict
directordict = pd.DataFrame(python_dict)

directordict.drop_duplicates(subset='id',inplace=True)
directordict.sort_values(by='id', inplace=True)
directordict.head(5000)
from pandas import Series
directordict['movieIDs'] = Series('', index=directordict.index)

for i in range(1000):
    crewlist = (literal_eval(cleanmeta['crew'][i]))
    for crew in crewlist:
        directordict.loc[directordict['id'] == crew['id'], 'movieIDs'] = directordict.loc[directordict['id'] == crew['id'], 'movieIDs'] + str(cleanmeta['id'][i])+','

directordict.head(2000)

#print(directordict['movieIDs'].values[0])
for i in range(len(directordict)):
    #print(directordict['movieIDs'].values[i])
    if not directordict['movieIDs'].values[i] == '':
        listdirector = directordict['movieIDs'].values[i][:-1].split(',')
        #print(listdirector)
        setdirector = set(listdirector)
        stringdirector = str(list(setdirector))
        #print(stringdirector)
        directordict['movieIDs'].values[i] = stringdirector
directordict['movieIDs']
# Out:
# 6441      ['1892', '11', '13155', '87', '1891', '1893', ...
# 110193
# 120513
# 11430                                       ['9487', '862']
# 37516                                       ['9487', '862']
# 104830
# 1682
# 80971
# 7227      ['686', '165', '13', '196', '105', '9431', '93...
# 156302                                               ['13']
# 46867                        ['29723', '9922', '13', '547']
# 45185                                        ['9566', '13']
# 16895                                  ['9922', '13', '73']
# 7235                            ['686', '196', '165', '13']
# 11799
# 5158                                  ['686', '8656', '13']
# 7229      ['686', '6283', '8592', '165', '13', '63020', ...
# 103804    ['686', '10249', '165', '13', '196', '105', '1...
# 17922
# 148055                                       ['1480', '15']
# 41813
# 124391
# 725                                           ['18', '101']
# ...

# %%
actordict['revbudRatio'] = Series(float(0), index=actordict.index)

# %%
actordict.head()
# Out:
#        cast_id             character                 credit_id  gender  id  \
# 69723       78       Baron Papanoida  584a4128c3a368141f01b620       2   1
# 6360         0     The Joker (voice)  56bde12c925141734d003684       2   2
# 16885        2         William Jones  54720ed292514112e70085bb       2   3
# 19171        7  Princess Leia Organa  52fe4a959251416c750e7137       1   4
# 85184       14           Buchhändler  52fe44b7c3a36847f80a61bf       2   5
#
#                 name  order                      profile_path  \
# 69723   George Lucas     24  /mDLDvsx8PaZoEThkBdyaG1JxPdf.jpg
# 6360     Mark Hamill      1  /ws544EgE5POxGJqq9LUfhnDrHtV.jpg
# 16885  Harrison Ford      2  /7CcoVFTogQgex2kJkXKMe8qHZrC.jpg
# 19171  Carrie Fisher      5  /pbleNurCYdrLFQMEnlQB2nkOR1O.jpg
# 85184  Peter Cushing      2  /fg7ufC0IMr6VasQzzdmTtX5ycQF.jpg
#
#                                                 movieIDs  revbudRatio
# 69723                                      ['87', '306']          0.0
# ...

# %%
directordict['revbudRatio'] = Series(float(0), index=directordict.index)

# %%
directordict.head()
# Out:
#                        credit_id  department  gender  id                 job  \
# 6441    5534b34ac3a368523e002fe6     Writing       2   1          Characters
# 110193  52fe44b2c3a36847f80a500f  Production       2   3  Executive Producer
# 120513  52fe4440c3a368484e01852d     Writing       1   4               Novel
# 11430   55eb2fbb92514106d60041ab     Writing       2   7          Screenplay
# 37516   52fe4675c3a368484e091e59  Production       2   8  Executive Producer
#
#                   name                      profile_path  \
# 6441      George Lucas  /mDLDvsx8PaZoEThkBdyaG1JxPdf.jpg
# 110193   Harrison Ford  /7CcoVFTogQgex2kJkXKMe8qHZrC.jpg
# 120513   Carrie Fisher  /pbleNurCYdrLFQMEnlQB2nkOR1O.jpg
# 11430   Andrew Stanton  /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
# 37516      Lee Unkrich  /bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg
#
#                                                  movieIDs  revbudRatio
# 6441    ['1892', '11', '13155', '87', '1891', '1893', ...          0.0
# ...

# %%
import numpy as np
for index, row in actordict.iterrows():
    strMovies = (row['movieIDs'])

    listMovies = strMovies.replace('[','').replace(']','').replace("'","").split(',')
    #print(listMovies)
    revbud = []
    if listMovies[0] == '':
        continue
    #print(index)
    for j in range(len(listMovies)):
        
        movieRow = (cleanmeta.loc[cleanmeta['id']==int(listMovies[j])])
        #print(listMovies[j])
        if len(movieRow['revenue']) > 1:
            rev = (movieRow['revenue'].iloc[0])
            bud = (movieRow['budget'].iloc[0])
        else:
            rev = (movieRow['revenue'].item())
            bud = (movieRow['budget'].item())
        revbud.append(float(rev/bud))
        #print(float(rev/bud))
    actordict['revbudRatio'][index] = float(np.mean(revbud))
    print(actordict['revbudRatio'][index])
    #print(revbud)
actordict.head()
# Out:
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 7.13851846143
# 39.3683615899
# 12.9635805541
# 17.0442967455
# 70.4907279091
# 26.7520967505
# 7.51747179964
# 4.14727612676
# 4.39286051917
# 2.0158400585
# 7.4267653913
# 4.0
# 8.17764383333
# 7.74096741688
# 5.24696451894
# 5.00587431343
# 4.87396402339
# 14.9888638909
# 10.127178871
# 0.753376866667
# 2.28383205753
# 1.79584578889
# 2.46946860852
# 3.59677954615
# 1.57434253889
# 4.70661797557
# 1.65119067124
# 1.88378000187
# 4.42104008822
# 5.42647417009
# 0.587142222222
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 0.00702247894623
# 4.79816954296
# ...

# %%
arr = [11.892857142857142, 2.38417978]
print(float(np.mean(arr)))
# Out:
# 7.138518461428571

# %%
actordict.to_csv("actortable.csv")

# %%
for index, row in directordict.iterrows():
    strMovies = (row['movieIDs'])

    listMovies = strMovies.replace('[','').replace(']','').replace("'","").split(',')
    #print(listMovies)
    revbud = []
    if listMovies[0] == '':
        continue
    print(index)
    for j in range(len(listMovies)):
        
        movieRow = (cleanmeta.loc[cleanmeta['id']==int(listMovies[j])])
        #print(listMovies[j])
        if len(movieRow['revenue']) > 1:
            rev = (movieRow['revenue'].iloc[0])
            bud = (movieRow['budget'].iloc[0])
        else:
            rev = (movieRow['revenue'].item())
            bud = (movieRow['budget'].item())
        revbud.append(float(rev/bud))
    directordict['revbudRatio'][index] = float(np.mean(revbud))
    print(directordict['revbudRatio'][index])
directordict.head()
# Out:
# 6441
# 15.7448755064
# 11430
# 7.73947912917
# 37516
# 7.73947912917
# 7227
# 8.24711031505
# 156302
# 12.3262799818
# 46867
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 4.1477564892
# 45185
# 6.33247107273
# 16895
# 4.58012141894
# 7235
# 7.16020163643
# 5158
# 5.36682638579
# 7229
# 4.43916261139
# 103804
# 6.86375858492
# 148055
# 15.1800647664
# 725
# 2.88137865972
# 81081
# 2.88137865972
# 15758
# 169774.429908
# 139914
# 0.00702247894623
# 113676
# 0.00702247894623
# 139916
# 0.00702247894623
# 88717
# 1.42912954933
# 139919
# 0.00702247894623
# 25373
# 0.556447288889
# 7117
# 5.01639941882
# 2625
# 2.16685398944
# 38270
# 3.18121831677
# 25377
# 0.556447288889
# 25376
# 7.617855
# 1861
# 1.28901253846
# 10600
# 1.80319274333
# ...

# %%
directordict.to_csv("directortable.csv")

# %%
print(metadata.shape)
cleanmeta = metadata[(metadata['adult'] == 'False') & (metadata['revenue'] != 0)]
cleanmeta['budget'] = cleanmeta.budget.astype(float)
cleanmeta['id'] = cleanmeta.id.astype(int)

cleanmeta = cleanmeta[cleanmeta['budget']!=0]
print(cleanmeta.shape)
cleanmeta.head()
# Out:
# (45466, 24)
# (5381, 24)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    adult                              belongs_to_collection      budget  \
# ...

# %%
cleanmeta = pd.merge(credits, cleanmeta, on='id')
cleanmeta.head(100)
# Out:
#                                                  cast  \
# 0   [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3   [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4   [{'cast_id': 1, 'character': 'Darren Francis T...
# 5   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 6   [{'cast_id': 1, 'character': 'Andrew Shepherd'...
# 7   [{'cast_id': 1, 'character': 'Richard Nixon', ...
# 8   [{'cast_id': 1, 'character': 'Morgan Adams', '...
# 9   [{'cast_id': 4, 'character': "Sam 'Ace' Rothst...
# 10  [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# 11  [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 12  [{'cast_id': 1, 'character': 'Ace Ventura', 'c...
# 13  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 14  [{'cast_id': 1, 'character': 'Chili Palmer', '...
# 15  [{'cast_id': 1, 'character': 'Robert Rath', 'c...
# ...

# %%
cleanmeta['castRevBudRatio'] = Series(float(0), index=cleanmeta.index)
cleanmeta.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew     id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844  False
# 2  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  False
# 3  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949  False
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...   9091  False
#
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# ...

# %%
import ast
for index, row in cleanmeta.iterrows():
    revbudavgs = []
    for cast_obj in ast.literal_eval(row['cast']):
        cast_id = cast_obj['id']
        cast_row = (actordict.loc[actordict['id']==cast_id])
        #print(cast_row['revbudRatio'].item())
        revbudavgs.append(cast_row['revbudRatio'].item())
    cleanmeta['castRevBudRatio'][index] = float(np.mean(revbudavgs))
    
    #print()
# Out:
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
cleanmeta.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew     id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844  False
# 2  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  False
# 3  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949  False
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...   9091  False
#
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# ...

# %%
print(metadata.shape)
directormeta = metadata[(metadata['adult'] == 'False') & (metadata['revenue'] != 0)]
directormeta['budget'] = directormeta.budget.astype(float)
directormeta['id'] = directormeta.id.astype(int)

directormeta = directormeta[directormeta['budget']!=0]
print(directormeta.shape)

directormeta.head()
# Out:
# (45466, 24)
# (5381, 24)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    adult                              belongs_to_collection      budget  \
# ...

# %%
directormeta = pd.merge(credits, directormeta, on='id')
directormeta.head(100)
# Out:
#                                                  cast  \
# 0   [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1   [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2   [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3   [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4   [{'cast_id': 1, 'character': 'Darren Francis T...
# 5   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 6   [{'cast_id': 1, 'character': 'Andrew Shepherd'...
# 7   [{'cast_id': 1, 'character': 'Richard Nixon', ...
# 8   [{'cast_id': 1, 'character': 'Morgan Adams', '...
# 9   [{'cast_id': 4, 'character': "Sam 'Ace' Rothst...
# 10  [{'cast_id': 6, 'character': 'Marianne Dashwoo...
# 11  [{'cast_id': 42, 'character': 'Ted the Bellhop...
# 12  [{'cast_id': 1, 'character': 'Ace Ventura', 'c...
# 13  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 14  [{'cast_id': 1, 'character': 'Chili Palmer', '...
# 15  [{'cast_id': 1, 'character': 'Robert Rath', 'c...
# ...

# %%
directormeta['castRevBudRatio'] = Series(float(0), index=cleanmeta.index)
directormeta.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew     id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844  False
# 2  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  False
# 3  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949  False
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...   9091  False
#
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# ...

# %%
for index, row in directormeta.iterrows():
    revbudavgs = []
    for cast_obj in ast.literal_eval(row['cast']):
        cast_id = cast_obj['id']
        cast_row = (actordict.loc[actordict['id']==cast_id])
        #print(cast_row['revbudRatio'].item())
        revbudavgs.append(cast_row['revbudRatio'].item())
    directormeta['castRevBudRatio'][index] = float(np.mean(revbudavgs))
# Out:
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2889: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/mfawaz/anaconda/lib/python3.6/site-packages/numpy/core/_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
directormeta.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 3  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew     id  adult  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862  False
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844  False
# 2  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  False
# 3  [{'credit_id': '52fe4292c3a36847f802916d', 'de...    949  False
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...   9091  False
#
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# ...

# %%
cleanmeta.to_csv("cleanmeta.csv")
directormeta.to_csv("directormeta.csv")
